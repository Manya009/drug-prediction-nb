# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv("Drug.csv")

# %%
df
# Out:
#                                                    Drug Disease  Gender  Age
# 0                  A CN Gel(Topical) 20gmA CN Soap 75gm    Acne    Male   23
# 1     A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...    Acne    Male   23
# 2                                ACGEL CL NANO Gel 15gm    Acne    Male   23
# 3                                   ACGEL NANO Gel 15gm    Acne    Male   23
# 4                                 Acleen 1% Lotion 25ml    Acne    Male   23
# ...                                                 ...     ...     ...  ...
# 4950                          Zosovir 400mg Tablet 28'S    AIDS    Male   37
# 4951  Zoster 800mg Tablet 10'SZoster 5% Cream 5gmZos...    AIDS    Male   37
# 4952                                Zovilam Tablet 60'S    AIDS  Female   57
# 4953  Zovir 400mg Tablet 10'SZovir 200mg Tablet 10'S...    AIDS  Female   37
# 4954  Zovirax 250mg InjectionZovirax 200mg Tablet 5'...    AIDS  Female   57
#
# [4955 rows x 4 columns]

# %%
df = df.dropna()

# %%
encoder = LabelEncoder()
df["Disease"] = encoder.fit_transform(df["Disease"])
df["Gender"] = encoder.fit_transform(df["Gender"])
#df["Drug"] = encoder.fit_transform(df["Drug"])

# %%
df
# Out:
#                                                    Drug  Disease  Gender  Age
# 0                  A CN Gel(Topical) 20gmA CN Soap 75gm        1       1   23
# 1     A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...        1       1   23
# 2                                ACGEL CL NANO Gel 15gm        1       1   23
# 3                                   ACGEL NANO Gel 15gm        1       1   23
# 4                                 Acleen 1% Lotion 25ml        1       1   23
# ...                                                 ...      ...     ...  ...
# 4950                          Zosovir 400mg Tablet 28'S        0       1   37
# 4951  Zoster 800mg Tablet 10'SZoster 5% Cream 5gmZos...        0       1   37
# 4952                                Zovilam Tablet 60'S        0       0   57
# 4953  Zovir 400mg Tablet 10'SZovir 200mg Tablet 10'S...        0       0   37
# 4954  Zovirax 250mg InjectionZovirax 200mg Tablet 5'...        0       0   57
#
# [4955 rows x 4 columns]

# %%
X = df.iloc[:,1:] #df.iloc[:, 1]
y = df.iloc[:,:1]

X_train, X_test, y_train, y_test =train_test_split(X, y, test_size = 0.2, random_state = 102)

# %%
nb_model = GaussianNB()
nb_model.fit(X, y)

prediction = nb_model.predict(X_test)
# Out:
# C:\Users\MANISH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#printing accuracy score in percentage %
print(accuracy_score(y_test, prediction)*100)
# Out:
# 4.742684157416751

# %%
import pickle

pickle.dump(nb_model, open('nb_drug.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('nb_drug.pkl', 'rb'))

# %%
pickled_model.predict(X_test)
# Out:
# array(["AF Ter Lotion 15mlAF Ter Cream 10gmAF Ter Tablet 7'S",
#        'DK Gel 30gm', "GIVOV 1mg Tablet 10's",
#        "D Loratin 5mg Tablet 10'S", 'DERMADEW B Bar 75gm',
#        "ALLRITE M Tablet 10'S", "ANGIOGLIM M1 Tablet 10's",
#        "ALLRITE M Tablet 10'S",
#        "FLOW 200MG TABLET 10'SFLOW 150MG CAPSULE 1'S",
#        'CLENCHIN Gel(Topical) 20gm', "Lariago DS Tablet 5'S",
#        "Gatrimav 100mg Tablet 6'S", "ADVOG M 0.3+ Tablet 10's",
#        "APRIGLIM MV 203 Tablet 10's", 'SLC 2% Facewash 50gm',
#        "CONA 150mg Tablet 1's", "Gatrimav 100mg Tablet 6'S",
#        'DK Gel 30gm', 'DK Gel 30gm', "1 AL M 10/5mg Tablet 10'S",
#        "Gatrimav 100mg Tablet 6'S", "D Loratin 5mg Tablet 10'S",
#        'DERMADEW B Bar 75gm',
#        'INFLUVAC NH JUNIOR 2016/2017 Injection(Pfs) 0.25ml',
#        "1 AL M 10/5mg Tablet 10'S", "ALLRITE M Tablet 10'S",
#        "APRIGLIM MV 203 Tablet 10's", "3D OHA 1G Tablet 10'S",
# ...
